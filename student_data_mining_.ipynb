# %%
#loading python libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#loading dataset from google drive
std_dataset= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/student-por.csv')

# %%
#show all columns
pd.options.display.max_columns=None
std_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
 #display first rows of dataset
std_dataset.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         0       yes     no   no
# 3    home   mother           1          3         0        no    yes   no
# 4    home   father           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
#displays last 5 rows of dataset
std_dataset.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
# ...

# %%
std_dataset.shape
# Out:
# (649, 33)

# %%
#list all name columns
std_dataset.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
#displays unique column variables
for i in std_dataset.columns:
    print(i.ljust(15),std_dataset[i].unique())
# Out:
# school          ['GP' 'MS']
# sex             ['F' 'M']
# age             [18 17 15 16 19 22 20 21]
# address         ['U' 'R']
# famsize         ['GT3' 'LE3']
# Pstatus         ['A' 'T']
# Medu            [4 1 3 2 0]
# Fedu            [4 1 2 3 0]
# Mjob            ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob            ['teacher' 'other' 'services' 'health' 'at_home']
# reason          ['course' 'other' 'home' 'reputation']
# guardian        ['mother' 'father' 'other']
# traveltime      [2 1 3 4]
# studytime       [2 3 1 4]
# failures        [0 3 1 2]
# schoolsup       ['yes' 'no']
# famsup          ['no' 'yes']
# paid            ['no' 'yes']
# activities      ['no' 'yes']
# nursery         ['yes' 'no']
# higher          ['yes' 'no']
# internet        ['no' 'yes']
# romantic        ['no' 'yes']
# famrel          [4 5 3 1 2]
# freetime        [3 2 4 1 5]
# goout           [4 3 2 1 5]
# Dalc            [1 2 5 3 4]
# Walc            [1 3 2 4 5]
# ...

# %%
#number of unique values
std_dataset.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      24
# G1            17
# G2            16
# G3            17
# dtype: int64

# %%
for i in std_dataset.select_dtypes(include='object'):
    print(std_dataset[i].value_counts())
# Out:
# GP    423
# MS    226
# Name: school, dtype: int64
# F    383
# M    266
# Name: sex, dtype: int64
# U    452
# R    197
# Name: address, dtype: int64
# GT3    457
# LE3    192
# Name: famsize, dtype: int64
# T    569
# A     80
# Name: Pstatus, dtype: int64
# other       258
# services    136
# at_home     135
# teacher      72
# health       48
# Name: Mjob, dtype: int64
# other       367
# services    181
# at_home      42
# teacher      36
# health       23
# Name: Fjob, dtype: int64
# course        285
# home          149
# reputation    143
# other          72
# Name: reason, dtype: int64
# mother    455
# father    153
# other      41
# Name: guardian, dtype: int64
# no     581
# yes     68
# Name: schoolsup, dtype: int64
# yes    398
# no     251
# Name: famsup, dtype: int64
# no     610
# yes     39
# Name: paid, dtype: int64
# no     334
# yes    315
# Name: activities, dtype: int64
# yes    521
# no     128
# Name: nursery, dtype: int64
# yes    580
# no      69
# ...

# %%
std_dataset["grades average"]=(std_dataset.G1+std_dataset.G2+std_dataset.G3)/3
std_dataset.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         0       yes     no   no
# 3    home   mother           1          3         0        no    yes   no
# 4    home   father           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %% [markdown]
# 2_Data Cleansing

# %%
std_dataset.isnull().any()
# Out:
# school            False
# sex               False
# age               False
# address           False
# famsize           False
# Pstatus           False
# Medu              False
# Fedu              False
# Mjob              False
# Fjob              False
# reason            False
# guardian          False
# traveltime        False
# studytime         False
# failures          False
# schoolsup         False
# famsup            False
# paid              False
# activities        False
# nursery           False
# higher            False
# internet          False
# romantic          False
# famrel            False
# freetime          False
# goout             False
# Dalc              False
# Walc              False
# health            False
# absences          False
# G1                False
# G2                False
# G3                False
# grades average    False
# dtype: bool

# %%
std_dataset.isnull().sum()
# Out:
# school            0
# sex               0
# age               0
# address           0
# famsize           0
# Pstatus           0
# Medu              0
# Fedu              0
# Mjob              0
# Fjob              0
# reason            0
# guardian          0
# traveltime        0
# studytime         0
# failures          0
# schoolsup         0
# famsup            0
# paid              0
# activities        0
# nursery           0
# higher            0
# internet          0
# romantic          0
# famrel            0
# freetime          0
# goout             0
# Dalc              0
# Walc              0
# health            0
# absences          0
# G1                0
# G2                0
# G3                0
# grades average    0
# dtype: int64

# %%
plt.figure(figsize=(15,8))
std_dataset.boxplot(color='#509e90',sym='r+')
# Out:
# <Axes: >

# %%
sorted(std_dataset)   #to find median for IQR
Q1= std_dataset.loc[:, std_dataset.columns!='failures'].quantile(0.25)
Q3= std_dataset.loc[:, std_dataset.columns!='failures'].quantile(0.75)
IQR= Q3-Q1
print(IQR)
# Out:
# age               2.000000
# Medu              2.000000
# Fedu              2.000000
# traveltime        1.000000
# studytime         1.000000
# famrel            1.000000
# freetime          1.000000
# goout             2.000000
# Dalc              1.000000
# Walc              2.000000
# health            3.000000
# absences          6.000000
# G1                3.000000
# G2                3.000000
# G3                4.000000
# grades average    3.333333
# dtype: float64

# %%
lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)
std_dataset2=std_dataset[~((std_dataset<lower_bound)|(std_dataset>upper_bound))]

plt.figure(figsize=(15,8))
std_dataset2.boxplot(color='#509e90',sym='rx')
# Out:
# <ipython-input-17-07a620d8a117>:3: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   std_dataset2=std_dataset[~((std_dataset<lower_bound)|(std_dataset>upper_bound))]
# <Axes: >

# %%
sns.boxplot(x='absences', data=std_dataset2,palette="crest")
# Out:
# <Axes: xlabel='absences'>

# %%
std_dataset3=std_dataset2[std_dataset2['absences']<16]
sns.boxplot(x='absences', data=std_dataset3,palette="crest")
# i understaneed from irene a.gyebi
# Out:
# <Axes: xlabel='absences'>

# %%
plt.figure(figsize=(15,8))
std_dataset3.boxplot(color='#509e90')
# Out:
# <Axes: >

# %%
std_dataset.describe().T
# Out:
#                 count       mean       std        min   25%        50%  \
# age             649.0  16.744222  1.218138  15.000000  16.0  17.000000
# Medu            649.0   2.514638  1.134552   0.000000   2.0   2.000000
# Fedu            649.0   2.306626  1.099931   0.000000   1.0   2.000000
# traveltime      649.0   1.568567  0.748660   1.000000   1.0   1.000000
# studytime       649.0   1.930663  0.829510   1.000000   1.0   2.000000
# failures        649.0   0.221880  0.593235   0.000000   0.0   0.000000
# famrel          649.0   3.930663  0.955717   1.000000   4.0   4.000000
# freetime        649.0   3.180277  1.051093   1.000000   3.0   3.000000
# goout           649.0   3.184900  1.175766   1.000000   2.0   3.000000
# Dalc            649.0   1.502311  0.924834   1.000000   1.0   1.000000
# Walc            649.0   2.280431  1.284380   1.000000   1.0   2.000000
# health          649.0   3.536210  1.446259   1.000000   2.0   4.000000
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(std_dataset2.corr(), vmin=-1, cmap="crest", annot=True)
# Out:
# <Axes: >

# %%
for i in std_dataset.columns:
    std_dataset[i].value_counts().plot(kind='bar',color='#509e90')
    plt.title(i)
    plt.show()

# %%
plt.figure(figsize=(6,5))
sns.barplot(x= 'sex', y = 'grades average', data = std_dataset2, errwidth=1,saturation=1, palette='crest')
plt.title('sex vs grades average \n')
plt.show()

b = sns.swarmplot(x='age', y='G3',hue='sex', data=std_dataset2,palette='crest')
b.axes.set_title('Does age affect final grade?\n', fontsize = 20)
b.set_xlabel('Age', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 47.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 60.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 53.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 40.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# 1. Is average <b>score</b> affected by <b>gender</b>?<br>
# Answer : According to above barplot average score is not affected by gender.it's not statistically prove.

# %% [markdown]
# 2. Is the **final grade** affected by **age**?<br>
# Answer: No distinct relation of **age** and **gender** was seen with **final grade**. it is not statistically prove.

# %%
plt.figure(figsize=(6,6))
f = std_dataset2.loc[std_dataset2['Pstatus']=='A'].count()[0]
m = std_dataset2.loc[std_dataset2['Pstatus']=='T'].count()[1]
plt.style.use('ggplot')
plt.pie([f,m], labels=['A','T'],explode=[0.1,0.1],startangle=0,labeldistance=1.2,autopct='%.2f %%',colors=["#1d6c8a","#509e90"])
plt.title('Pstatus\n\n A  vs  T ')
plt.show()

plt.figure(figsize=(6,6))
sns.barplot(x= 'Pstatus', y = 'grades average', data = std_dataset2, errwidth=1,saturation=1, palette='crest')
plt.title('Pstatus vs grades average')
# Out:
# Text(0.5, 1.0, 'Pstatus vs grades average')

# %% [markdown]
# 3. Is the **student's grades** affected by the **cohabitation status** of parents (binary: "T" - living together or "A" - apart -)? <br>
# Answer:According to above chart, students grades is not affected by cohabitation status.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x= 'age', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
plt.title('age vs grades average')
# Out:
# Text(0.5, 1.0, 'age vs grades average')

# %% [markdown]
# 4. Is the **average score** affected by **advanced age**?<br>
# Answer: While **grade** seems to gradually **decreas**e with **age**, it is noticed that it **increases** in the **twenties**.

# %%
plt.figure(figsize=(15,8))
sns.boxplot([std_dataset3['traveltime'],std_dataset3['grades average']],color='#509e90')
plt.show()

# %% [markdown]
# 5. Is the student's **grade**s affected by **travel time**?<br>
# Answer: **Yes**, it is seen that when the **travel time** is less for the students, **exam scores** tend to grow.

# %%
plt.figure(figsize=(10,8))
colors = sns.color_palette('crest')[0:5]
std_dataset.Mjob.value_counts().plot(kind='pie', autopct='%.0f%%', colors = colors)
plt.title('Mjob proportion in %')
plt.legend()

# %%
plt.figure(figsize= (15,5))
plt.subplot(1,2,1)
order_by = std_dataset.groupby('Fedu')['G1'].median().sort_values(ascending = False).index
sns.boxplot(x = std_dataset['Fedu'], y = std_dataset['G1'],order = order_by,palette="crest")
plt.xticks(rotation = 90)
plt.title('Fedu v/s G1')

plt.subplot(1,2,2)
order_by = std_dataset.groupby('Medu')['G1'].median().sort_values(ascending = False).index
sns.boxplot(x = std_dataset['Medu'], y = std_dataset['G1'],order = order_by,palette="crest")
plt.xticks(rotation = 90)
plt.title('Medu v/s G1')

plt.show()

# %% [markdown]
# 6. Is the student's **grade** affected by their **parent's** education status?<br>
# Answer: Yes, when **parent's** are educated, **student's** grade seems to be higher. it not statistically prove but student grade is directly depend on their parent's education.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x= 'failures', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
plt.figure(figsize=(8,5))
sns.barplot(x= 'studytime', y = 'failures', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
# Out:
# <Axes: xlabel='studytime', ylabel='failures'>

# %%
sns.regplot(x='studytime', y='grades average', data=std_dataset2,color="#509e90")
# Out:
# <Axes: xlabel='studytime', ylabel='grades average'>

# %% [markdown]
# ###Conclusion
# * Results are seen exactly as **expected**. When students **study more** and focus on their studies, they tend to **score more** on their assignments and quizzes which in turn helps to **improve the resul**ts.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x= 'famrel', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
plt.figure(figsize=(8,5))
sns.barplot(x= 'higher', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')

plt.figure(figsize=(8,5))
sns.barplot(x= 'health', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
# Out:
# <Axes: xlabel='health', ylabel='grades average'>

# %% [markdown]
# ###conclusion
# * It is seen that when the **grades** are **higher**, more students want to **enroll** in **higher education**.
# 7. Is the **student's grad**e affected by the **family relations**?<br>
# Answer:**Yes**, It seems that when the **family relationships** are better, students tend to **score highe**r marks.
#
# 8. Is the student's grade affected by their health condition?<br>
# Answer: Yes, students with **poor health** tend to score **higher marks**.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x= 'G1', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
plt.figure(figsize=(8,5))
sns.barplot(x= 'G2', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')

plt.figure(figsize=(8,5))
sns.barplot(x= 'G3', y = 'grades average', data = std_dataset2, errwidth=3,saturation=1, palette='crest')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <Axes: xlabel='G3', ylabel='grades average'>

# %% [markdown]
# ###Conclusion
# * As per the graph, students with higher grades in first, second and final grade have the higher grade in average score.
# * Likewise, students with higher grades in first and second period second have the higher score in final exam.

# %% [markdown]
# **Correlation**

# %%
std_dataset.corr()['G3'].sort_values()
# Out:
# failures         -0.393316
# Dalc             -0.204719
# Walc             -0.176619
# traveltime       -0.127173
# freetime         -0.122705
# age              -0.106505
# health           -0.098851
# absences         -0.091379
# goout            -0.087641
# famrel            0.063361
# Fedu              0.211800
# Medu              0.240151
# studytime         0.249789
# G1                0.826387
# G2                0.918548
# grades average    0.961829
# G3                1.000000
# Name: G3, dtype: float64

# %%
print("\nNumber of students in the two schools.\n")
print(std_dataset['school'].value_counts())
sns.pairplot(
    std_dataset2,
    x_vars=["G1", "G2"],
    y_vars=["G1", "G2", "G3"],
    hue="school",
    palette="crest"
)
# Out:
# Number of students in the two schools.
#
# GP    423
# MS    226
# Name: school, dtype: int64

# %% [markdown]
# ###Conclusion
#
# * From the **final analysi**s and graphs, we see that the **scores** of students of Gp school score **higher marks** in all the exams than the students of School MS but this data cannot be taken as **enough evidence** as the number of students in both school varies where GP has **34**9 and MS has **46**.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy
labels = std_dataset['G3']

# %%
# selecting the most correlated values and dropping the others
labels = std_dataset['G3']

# drop the school and grade columns
std_dataset = std_dataset.drop(['school', 'G1', 'G2'], axis='columns')

# One-Hot Encoding of Categorical Variables
std_dataset = pd.get_dummies(std_dataset)

# %%
# Find correlations with the Grade
most_correlated = std_dataset.corr().abs()['G3'].sort_values(ascending=False)

# Maintain the top 8 most correlation features with Grade
most_correlated = most_correlated[:9]
most_correlated
# Out:
# G3                1.000000
# grades average    0.961829
# failures          0.393316
# higher_no         0.332172
# higher_yes        0.332172
# studytime         0.249789
# Medu              0.240151
# Fedu              0.211800
# Dalc              0.204719
# Name: G3, dtype: float64

# %%
std_dataset = std_dataset.loc[:, most_correlated.index]
std_dataset.head()
# Out:
#    G3  grades average  failures  higher_no  higher_yes  studytime  Medu  Fedu  \
# 0  11        7.333333         0          0           1          2     4     4
# 1  11       10.333333         0          0           1          2     1     1
# 2  12       12.333333         0          0           1          2     1     1
# 3  14       14.000000         0          0           1          3     4     2
# 4  13       12.333333         0          0           1          2     3     3
#
#    Dalc
# 0     1
# 1     1
# 2     2
# 3     1
# 4     1

# %% [markdown]
# **Now we will analyse these variables and then train a model** <br>
# Student with less previous failures usually score higher¶

# %%
b = sns.swarmplot(x=std_dataset['failures'],y=std_dataset['G3'],palette="crest")
b.axes.set_title('Students with less failures score higher', fontsize = 30)
b.set_xlabel('Number of failures', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()
# Out:
# <ipython-input-51-63f90ec7f1f1>:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   b = sns.swarmplot(x=std_dataset['failures'],y=std_dataset['G3'],palette="crest")
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 67.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 11.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 71.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
family_ed = std_dataset['Fedu'] + std_dataset['Medu']
b = sns.boxplot(x=family_ed,y=std_dataset['G3'], palette="crest")
b.axes.set_title('Educated families result in higher grades', fontsize = 30)
b.set_xlabel('Family education (Mother + Father)', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()

# %%
b = sns.swarmplot(x=family_ed,y=std_dataset['G3'],palette="crest")
b.axes.set_title('Educated families result in higher grades', fontsize = 30)
b.set_xlabel('Family education (Mother + Father)', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()
# Out:
# <ipython-input-53-b66248733719>:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   b = sns.swarmplot(x=family_ed,y=std_dataset['G3'],palette="crest")
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 45.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 42.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 58.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# **Higher education** <br>
# Higher education was a categorical variable with values yes and no. Since we used one hot encoding it has been converted to 2 variables. So we can safely eliminate one of them (since the values are compliments of each other). We will eliminate higher_no, since higher_yes is more intuitive.

# %%
student = std_dataset.drop('higher_no', axis='columns')
student.head()
# Out:
#    G3  grades average  failures  higher_yes  studytime  Medu  Fedu  Dalc
# 0  11        7.333333         0           1          2     4     4     1
# 1  11       10.333333         0           1          2     1     1     1
# 2  12       12.333333         0           1          2     1     1     2
# 3  14       14.000000         0           1          3     4     2     1
# 4  13       12.333333         0           1          2     3     3     1

# %%
b = sns.boxplot(x = std_dataset['higher_yes'], y=std_dataset['G3'],palette="crest")
b.axes.set_title('Students who wish to go for higher studies score more', fontsize = 30)
b.set_xlabel('Higher education (1 = Yes)', fontsize = 20)
b.set_ylabel('Final Grade', fontsize = 20)
plt.show()

# %% [markdown]
# **Modeling**

# %%
# splitting the data into training and testing data (75% and 25%)
# we mention the random state to achieve the same split everytime we run the code
X_train, X_test, y_train, y_test = train_test_split(std_dataset, labels, test_size = 0.25, random_state=42)

# %%
X_train.head()
# Out:
#      G3  grades average  failures  higher_no  higher_yes  studytime  Medu  \
# 213  11       10.666667         0          0           1          2     4
# 43   10        9.666667         0          0           1          1     2
# 42   15       14.666667         0          0           1          2     4
# 73   14       13.333333         0          0           1          1     3
# 494   9        8.666667         0          1           0          2     1
#
#      Fedu  Dalc
# 213     4     1
# 43      2     1
# 42      4     1
# 73      1     2
# 494     2     1

# %% [markdown]
# MAE - Mean Absolute Error <br>
# RMSE - Root Mean Square Error

# %%
# Calculate mae and rmse
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))

    return mae, rmse

# %% [markdown]
# **Naive baseline is the median prediction**

# %%
# find the median
median_pred = X_train['G3'].median()

# create a list with all values as median
median_preds = [median_pred for _ in range(len(X_test))]

# store the true G3 values for passing into the function
true = X_test['G3']

# %%
# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, true)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# Median Baseline  MAE: 2.3436
# Median Baseline RMSE: 3.1835

# %%
# Evaluate several ml models by training on training set and testing on testing set
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted']
    X_train = X_train.drop('G3', axis='columns')
    X_test = X_test.drop('G3', axis='columns')

    # Instantiate the models
    model1 = LinearRegression()
    model3 = RandomForestRegressor(n_estimators=100)
    model4 = ExtraTreesRegressor(n_estimators=100)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=50)

    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)

    # Train and predict with each model
    for i, model in enumerate([model1, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)

        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))

        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]

    return results

# %%
results = evaluate(X_train, X_test, y_train, y_test)
results
# Out:
#                         mae      rmse
# Linear Regression  0.618465  0.882167
# Random Forest      0.595336   0.88029
# Extra Trees         0.59363   0.88782
# SVM                0.763713  1.415372
# Gradient Boosted   0.533835  0.812741

# %%
plt.figure(figsize=(12, 8))

# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = '#509e90', ax = ax, fontsize=20)
plt.title('Model Mean Absolute Error', fontsize=20)
plt.ylabel('MAE', fontsize=20)

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = '#1d6c8a', ax = ax, fontsize=20)
plt.title('Model Root Mean Squared Error', fontsize=20)
plt.ylabel('RMSE',fontsize=20)

plt.show()
